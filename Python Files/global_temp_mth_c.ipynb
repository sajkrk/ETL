# %%
import datapackage
import pandas as pd

# %%
data_url = 'https://datahub.io/core/global-temp/datapackage.json'

# %%
#load data paclage into storage
package = datapackage.Package(data_url)

# %%
df_list = []

# %%
#load tabular data
resources = package.resources
for resource in resources:
    if resource.tabular:
        data = pd.read_csv(resource.descriptor['path'])
        df_list.append(data)

# %%
len(df_list)
# Out:
# 4

# %%
df1 = df_list[0]
df1
# Out:
#       Source  Year    Mean
# 0       GCAG  2016  0.9363
# 1    GISTEMP  2016  0.9900
# 2       GCAG  2015  0.8998
# 3    GISTEMP  2015  0.8700
# 4       GCAG  2014  0.7408
# 5    GISTEMP  2014  0.7400
# 6       GCAG  2013  0.6679
# 7    GISTEMP  2013  0.6500
# 8       GCAG  2012  0.6240
# 9    GISTEMP  2012  0.6300
# 10      GCAG  2011  0.5788
# 11   GISTEMP  2011  0.6000
# 12      GCAG  2010  0.7014
# 13   GISTEMP  2010  0.7100
# 14      GCAG  2009  0.6367
# 15   GISTEMP  2009  0.6400
# 16      GCAG  2008  0.5419
# 17   GISTEMP  2008  0.5400
# 18      GCAG  2007  0.6100
# 19   GISTEMP  2007  0.6600
# 20      GCAG  2006  0.6125
# 21   GISTEMP  2006  0.6300
# 22      GCAG  2005  0.6585
# 23   GISTEMP  2005  0.6900
# 24      GCAG  2004  0.5783
# 25   GISTEMP  2004  0.5500
# 26      GCAG  2003  0.6134
# 27   GISTEMP  2003  0.6200
# 28      GCAG  2002  0.6023
# 29   GISTEMP  2002  0.6300
# ..       ...   ...     ...
# 244     GCAG  1894 -0.2808
# 245  GISTEMP  1894 -0.3100
# 246     GCAG  1893 -0.3212
# 247  GISTEMP  1893 -0.3000
# 248     GCAG  1892 -0.3062
# 249  GISTEMP  1892 -0.2700
# 250     GCAG  1891 -0.2532
# 251  GISTEMP  1891 -0.2400
# 252     GCAG  1890 -0.3220
# 253  GISTEMP  1890 -0.3700
# 254     GCAG  1889 -0.0982
# 255  GISTEMP  1889 -0.1200
# 256     GCAG  1888 -0.1471
# 257  GISTEMP  1888 -0.2000
# 258     GCAG  1887 -0.2489
# 259  GISTEMP  1887 -0.3300
# 260     GCAG  1886 -0.2003
# 261  GISTEMP  1886 -0.3100
# 262     GCAG  1885 -0.2125
# 263  GISTEMP  1885 -0.3200
# 264     GCAG  1884 -0.2009
# 265  GISTEMP  1884 -0.2800
# 266     GCAG  1883 -0.1424
# 267  GISTEMP  1883 -0.2100
# 268     GCAG  1882 -0.0648
# 269  GISTEMP  1882 -0.1000
# 270     GCAG  1881 -0.0628
# 271  GISTEMP  1881 -0.1200
# 272     GCAG  1880 -0.1148
# 273  GISTEMP  1880 -0.2000
#
# [274 rows x 3 columns]

# %%
df2 = df_list[1]

# %%
df1.to_csv("GlobalTemp.csv")

# %%
df2.to_csv("GlobalTempMonthly.csv")
