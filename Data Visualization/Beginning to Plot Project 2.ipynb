# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
climate_data = pd.read_csv("BootcampStuff/project2-grp6-etl/final04/final04_1974.csv")

# %%
climate_data.head()
# Out:
#      Year  Mean Glacier Mass  Mean Global Temp   Total  Gas Fuel  Liquid Fuel  \
# 0  1974.0            -10.613           -0.0719  4623.0     597.0       2245.0
# 1  1975.0            -10.534            0.0034  4596.0     604.0       2132.0
# 2  1976.0            -10.633           -0.0792  4864.0     630.0       2314.0
# 3  1977.0            -10.682            0.1978  5026.0     650.0       2398.0
# 4  1978.0            -10.754            0.1123  5087.0     680.0       2392.0
#
#    Solid Fuel  Cement  Gas Flaring  Per Capita  ...  24S-24N  90S-24S  \
# 0      1579.0    96.0        107.0        1.16  ...     0.17    -0.03
# 1      1673.0    95.0         92.0        1.13  ...    -0.05    -0.24
# 2      1710.0   103.0        108.0        1.18  ...    -0.07    -0.17
# 3      1765.0   108.0        104.0        1.19  ...    -0.19    -0.24
# 4      1793.0   116.0        106.0        1.19  ...    -0.19    -0.23
#
#    64N-90N  44N-64N  24N-44N  EQU-24N  24S-EQU  44S-24S  64S-44S  90S-64S
# ...

# %%
climate_data["Mean Glacier Mass"] = pd.to_numeric(climate_data["Mean Glacier Mass"])

climate_data.plot(kind="scatter", x="Year", y="Mean Glacier Mass", grid=True, figsize=(20,20), title="plotttyplot")

# %%
climate_data["Mean Global Temp"] = pd.to_numeric(climate_data["Mean Global Temp"])

climate_data.plot(kind="scatter", x="Year", y="Mean Global Temp", grid=True, figsize=(20,20), title="Mean Global Temp")

# %%
climate_data["Per Capita"] = pd.to_numeric(climate_data["Per Capita"])

climate_data.plot(kind="scatter", x="Year", y="Per Capita", grid=True, figsize=(20,20), title="Per Capita")

# %%
climate_data["NHem"] = pd.to_numeric(climate_data["NHem"])

climate_data.plot(kind="scatter", x="Year", y="NHem", grid=True, figsize=(20,20), title="NHem")

# %%
climate_data["SHem"] = pd.to_numeric(climate_data["SHem"])

climate_data.plot(kind="scatter", x="Year", y="SHem", grid=True, figsize=(20,20), title="SHem")
